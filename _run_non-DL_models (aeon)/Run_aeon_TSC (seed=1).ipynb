# %%
data_dir = "/Users/yoom618-macmini/Downloads/Multivariate_ts"

# %%
# %pip install aeon seaborn torch numpy pandas

# %%
import sys
import random
import numpy as np
import time
import gc
import warnings
from sklearn.metrics import accuracy_score

warnings.filterwarnings("ignore")

# %%
from aeon.classification.distance_based import KNeighborsTimeSeriesClassifier as DTWClassifier
from aeon.classification.convolution_based import RocketClassifier, MultiRocketHydraClassifier, HydraClassifier
from aeon.classification.hybrid import HIVECOTEV2
from aeon.datasets import load_classification
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
UEA_MTSC30 = ['EthanolConcentration',
              'FaceDetection',
              'Handwriting',
              'Heartbeat',
              'JapaneseVowels',
              'PEMS-SF',
              'SelfRegulationSCP1',
              'SelfRegulationSCP2',
              'SpokenArabicDigits',
              'UWaveGestureLibrary',
              'ArticularyWordRecognition',
              'AtrialFibrillation',
              'BasicMotions',
              'CharacterTrajectories',
              'Cricket',
              'DuckDuckGeese',
              'Epilepsy',
              'ERing',
              'FingerMovements',
              'HandMovementDirection',
              'InsectWingbeat',
              'Libras',
              'LSST',
              'MotorImagery',
              'NATOPS',
              'PenDigits',
              'PhonemeSpectra',
              'RacketSports',
              'StandWalkJump',
              'EigenWorms',]

SEED = 1

# %%
def timeit(func):
    def wrapper(*args, **kwargs):
        start_time = time.time()
        result = func(*args, **kwargs)
        end_time = time.time()
        print(f"\tFunction {func.__name__} took {end_time - start_time:.4f} seconds to execute.")
        return result
    return wrapper

# %%
@timeit
def train_model(classifier, X_train, y_train):
    classifier.fit(X_train, y_train)
    return classifier

@timeit
def eval_model(classifier, X_test, y_test):
    y_pred = classifier.predict(X_test)
    return accuracy_score(y_test, y_pred)

# %%
models = {
    # 'DTW': DTWClassifier(n_jobs=8),  # result will be same regardless of random_state
    'Rocket': RocketClassifier(random_state=SEED, n_jobs=8),
    'Hydra': HydraClassifier(random_state=SEED, n_jobs=8),
    'Hive-Cote v2': HIVECOTEV2(time_limit_in_minutes=0.2, random_state=SEED, n_jobs=8),
    'MultiRocket-Hydra': MultiRocketHydraClassifier(random_state=SEED, n_jobs=8),
}
for dname in UEA_MTSC30:
    print(f"===== {dname} =====")
    X_train, y_train = load_classification(dname, split="train", extract_path=data_dir, load_equal_length=True)
    X_test, y_test = load_classification(dname, split="test", extract_path=data_dir, load_equal_length=True)
    print(f"Train shape: {X_train.shape}, Test shape: {X_test.shape}")
    
    for model in models:
        print(f"\t===== {model} =====")
        # paddding to make the length >= 9
        if X_train.shape[2] < 10 and model == 'MultiRocket-Hydra':
            X_train = np.pad(X_train, ((0, 0), (0, 0), (0, 10 - X_train.shape[2])), 'edge')
            X_test = np.pad(X_test, ((0, 0), (0, 0), (0, 10 - X_test.shape[2])), 'edge')
            print(f"\tPadded Train shape: {X_train.shape}, Padded Test shape: {X_test.shape}")
        
        random.seed(SEED)
        np.random.seed(SEED)
        models[model] = train_model(models[model], X_train, y_train)
        accuracy = eval_model(models[model], X_test, y_test)
        print(f"\t{model} on {dname}: {accuracy * 100} %")
        print(f"\t{model} on {dname} object size is {sys.getsizeof(models[model])/1024} KB")
        models[model].reset(keep=None)
        gc.collect()
# Out:
# ===== EthanolConcentration =====
# Train shape: (261, 3, 1751), Test shape: (263, 3, 1751)
# 	===== Rocket =====
# 	Function train_model took 10.5907 seconds to execute.
# 	Function eval_model took 10.7974 seconds to execute.
# 	Rocket on EthanolConcentration: 44.48669201520912 %
# 	Rocket on EthanolConcentration object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 17.7302 seconds to execute.
# 	Function eval_model took 17.1484 seconds to execute.
# 	Hydra on EthanolConcentration: 52.851711026615966 %
# 	Hydra on EthanolConcentration object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 70.5523 seconds to execute.
# 	Function eval_model took 65.2735 seconds to execute.
# 	Hive-Cote v2 on EthanolConcentration: 48.28897338403042 %
# 	Hive-Cote v2 on EthanolConcentration object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====
# 	Function train_model took 18.4242 seconds to execute.
# 	Function eval_model took 15.3034 seconds to execute.
# 	MultiRocket-Hydra on EthanolConcentration: 55.13307984790875 %
# 	MultiRocket-Hydra on EthanolConcentration object size is 0.046875 KB
# ===== FaceDetection =====
# Train shape: (5890, 144, 62), Test shape: (3524, 144, 62)
# 	===== Rocket =====
# 	Function train_model took 62.7471 seconds to execute.
# 	Function eval_model took 9.5132 seconds to execute.
# 	Rocket on FaceDetection: 61.038592508513055 %
# 	Rocket on FaceDetection object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 27.1472 seconds to execute.
# 	Function eval_model took 9.9793 seconds to execute.
# 	Hydra on FaceDetection: 52.894438138479 %
# 	Hydra on FaceDetection object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 3913.7356 seconds to execute.
# 	Function eval_model took 288.1860 seconds to execute.
# 	Hive-Cote v2 on FaceDetection: 59.080590238365495 %
# 	Hive-Cote v2 on FaceDetection object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====
# 	Function train_model took 88.6946 seconds to execute.
# 	Function eval_model took 18.0136 seconds to execute.
# 	MultiRocket-Hydra on FaceDetection: 61.29398410896708 %
# 	MultiRocket-Hydra on FaceDetection object size is 0.046875 KB
# ===== Handwriting =====
# Train shape: (150, 3, 152), Test shape: (850, 3, 152)
# 	===== Rocket =====
# 	Function train_model took 0.5354 seconds to execute.
# 	Function eval_model took 2.7245 seconds to execute.
# 	Rocket on Handwriting: 58.58823529411765 %
# 	Rocket on Handwriting object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 2.1592 seconds to execute.
# 	Function eval_model took 12.6002 seconds to execute.
# 	Hydra on Handwriting: 47.529411764705884 %
# 	Hydra on Handwriting object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 11.8851 seconds to execute.
# 	Function eval_model took 49.1494 seconds to execute.
# 	Hive-Cote v2 on Handwriting: 56.00000000000001 %
# 	Hive-Cote v2 on Handwriting object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====
# 	Function train_model took 1.7366 seconds to execute.
# 	Function eval_model took 7.5335 seconds to execute.
# 	MultiRocket-Hydra on Handwriting: 53.529411764705884 %
# 	MultiRocket-Hydra on Handwriting object size is 0.046875 KB
# ===== Heartbeat =====
# Train shape: (204, 61, 405), Test shape: (205, 61, 405)
# 	===== Rocket =====
# 	Function train_model took 3.7091 seconds to execute.
# 	Function eval_model took 3.6823 seconds to execute.
# 	Rocket on Heartbeat: 74.63414634146342 %
# 	Rocket on Heartbeat object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 3.7023 seconds to execute.
# 	Function eval_model took 3.5867 seconds to execute.
# 	Hydra on Heartbeat: 78.53658536585367 %
# 	Hydra on Heartbeat object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 48.3079 seconds to execute.
# 	Function eval_model took 46.9532 seconds to execute.
# 	Hive-Cote v2 on Heartbeat: 76.58536585365854 %
# 	Hive-Cote v2 on Heartbeat object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====
# 	Function train_model took 7.2479 seconds to execute.
# 	Function eval_model took 5.1044 seconds to execute.
# 	MultiRocket-Hydra on Heartbeat: 77.07317073170732 %
# 	MultiRocket-Hydra on Heartbeat object size is 0.046875 KB
# ===== JapaneseVowels =====
# Train shape: (270, 12, 25), Test shape: (370, 12, 25)
# 	===== Rocket =====
# 	Function train_model took 0.3844 seconds to execute.
# 	Function eval_model took 0.4153 seconds to execute.
# 	Rocket on JapaneseVowels: 83.78378378378379 %
# 	Rocket on JapaneseVowels object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 0.4462 seconds to execute.
# 	Function eval_model took 0.3848 seconds to execute.
# 	Hydra on JapaneseVowels: 98.37837837837839 %
# 	Hydra on JapaneseVowels object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 13.7379 seconds to execute.
# 	Function eval_model took 12.3912 seconds to execute.
# 	Hive-Cote v2 on JapaneseVowels: 85.4054054054054 %
# 	Hive-Cote v2 on JapaneseVowels object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====
# 	Function train_model took 0.6432 seconds to execute.
# 	Function eval_model took 0.6930 seconds to execute.
# 	MultiRocket-Hydra on JapaneseVowels: 98.37837837837839 %
# 	MultiRocket-Hydra on JapaneseVowels object size is 0.046875 KB
# ===== PEMS-SF =====
# Train shape: (267, 963, 144), Test shape: (173, 963, 144)
# 	===== Rocket =====
# 	Function train_model took 2.0288 seconds to execute.
# 	Function eval_model took 1.2331 seconds to execute.
# 	Rocket on PEMS-SF: 83.23699421965318 %
# 	Rocket on PEMS-SF object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 2.8769 seconds to execute.
# 	Function eval_model took 1.7133 seconds to execute.
# 	Hydra on PEMS-SF: 81.5028901734104 %
# 	Hydra on PEMS-SF object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 121.7772 seconds to execute.
# 	Function eval_model took 40.1404 seconds to execute.
# 	Hive-Cote v2 on PEMS-SF: 97.10982658959537 %
# 	Hive-Cote v2 on PEMS-SF object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====
# 	Function train_model took 6.6731 seconds to execute.
# 	Function eval_model took 4.7082 seconds to execute.
# 	MultiRocket-Hydra on PEMS-SF: 78.61271676300578 %
# 	MultiRocket-Hydra on PEMS-SF object size is 0.046875 KB
# ===== SelfRegulationSCP1 =====
# Train shape: (268, 6, 896), Test shape: (293, 6, 896)
# 	===== Rocket =====
# 	Function train_model took 7.8439 seconds to execute.
# 	Function eval_model took 8.7255 seconds to execute.
# 	Rocket on SelfRegulationSCP1: 84.98293515358361 %
# 	Rocket on SelfRegulationSCP1 object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 8.9313 seconds to execute.
# 	Function eval_model took 9.2602 seconds to execute.
# 	Hydra on SelfRegulationSCP1: 87.03071672354949 %
# 	Hydra on SelfRegulationSCP1 object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 55.1206 seconds to execute.
# 	Function eval_model took 56.0232 seconds to execute.
# 	Hive-Cote v2 on SelfRegulationSCP1: 85.32423208191126 %
# 	Hive-Cote v2 on SelfRegulationSCP1 object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====
# 	Function train_model took 10.9861 seconds to execute.
# 	Function eval_model took 12.5766 seconds to execute.
# 	MultiRocket-Hydra on SelfRegulationSCP1: 93.1740614334471 %
# 	MultiRocket-Hydra on SelfRegulationSCP1 object size is 0.046875 KB
# ===== SelfRegulationSCP2 =====
# Train shape: (200, 7, 1152), Test shape: (180, 7, 1152)
# 	===== Rocket =====
# 	Function train_model took 8.4553 seconds to execute.
# 	Function eval_model took 7.6182 seconds to execute.
# 	Rocket on SelfRegulationSCP2: 55.55555555555556 %
# 	Rocket on SelfRegulationSCP2 object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 8.3074 seconds to execute.
# 	Function eval_model took 7.9501 seconds to execute.
# 	Hydra on SelfRegulationSCP2: 54.44444444444444 %
# 	Hydra on SelfRegulationSCP2 object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 66.1185 seconds to execute.
# 	Function eval_model took 58.1104 seconds to execute.
# 	Hive-Cote v2 on SelfRegulationSCP2: 50.55555555555556 %
# 	Hive-Cote v2 on SelfRegulationSCP2 object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====
# 	Function train_model took 10.5241 seconds to execute.
# 	Function eval_model took 9.3357 seconds to execute.
# 	MultiRocket-Hydra on SelfRegulationSCP2: 53.333333333333336 %
# 	MultiRocket-Hydra on SelfRegulationSCP2 object size is 0.046875 KB
# ===== SpokenArabicDigits =====
# Train shape: (6599, 13, 65), Test shape: (2199, 13, 65)
# 	===== Rocket =====
# 	Function train_model took 81.5227 seconds to execute.
# 	Function eval_model took 6.1226 seconds to execute.
# 	Rocket on SpokenArabicDigits: 99.22692132787631 %
# 	Rocket on SpokenArabicDigits object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 67.4083 seconds to execute.
# 	Function eval_model took 8.7537 seconds to execute.
# 	Hydra on SpokenArabicDigits: 98.3174170077308 %
# 	Hydra on SpokenArabicDigits object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 2012.1073 seconds to execute.
# 	Function eval_model took 114.1078 seconds to execute.
# 	Hive-Cote v2 on SpokenArabicDigits: 99.09049567985448 %
# 	Hive-Cote v2 on SpokenArabicDigits object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====
# 	Function train_model took 108.8515 seconds to execute.
# 	Function eval_model took 11.4671 seconds to execute.
# 	MultiRocket-Hydra on SpokenArabicDigits: 99.0450204638472 %
# 	MultiRocket-Hydra on SpokenArabicDigits object size is 0.046875 KB
# ===== UWaveGestureLibrary =====
# Train shape: (120, 3, 315), Test shape: (320, 3, 315)
# 	===== Rocket =====
# 	Function train_model took 0.8184 seconds to execute.
# 	Function eval_model took 2.0813 seconds to execute.
# 	Rocket on UWaveGestureLibrary: 93.75 %
# 	Rocket on UWaveGestureLibrary object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 1.8218 seconds to execute.
# 	Function eval_model took 4.2363 seconds to execute.
# 	Hydra on UWaveGestureLibrary: 90.625 %
# 	Hydra on UWaveGestureLibrary object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 11.8158 seconds to execute.
# 	Function eval_model took 24.6434 seconds to execute.
# 	Hive-Cote v2 on UWaveGestureLibrary: 94.0625 %
# 	Hive-Cote v2 on UWaveGestureLibrary object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====
# 	Function train_model took 2.2310 seconds to execute.
# 	Function eval_model took 5.0460 seconds to execute.
# 	MultiRocket-Hydra on UWaveGestureLibrary: 94.0625 %
# 	MultiRocket-Hydra on UWaveGestureLibrary object size is 0.046875 KB
# ===== ArticularyWordRecognition =====
# Train shape: (275, 9, 144), Test shape: (300, 9, 144)
# 	===== Rocket =====
# 	Function train_model took 1.6691 seconds to execute.
# 	Function eval_model took 1.7539 seconds to execute.
# 	Rocket on ArticularyWordRecognition: 99.33333333333333 %
# 	Rocket on ArticularyWordRecognition object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 2.1071 seconds to execute.
# 	Function eval_model took 2.5247 seconds to execute.
# 	Hydra on ArticularyWordRecognition: 99.33333333333333 %
# 	Hydra on ArticularyWordRecognition object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 19.2300 seconds to execute.
# 	Function eval_model took 17.1214 seconds to execute.
# 	Hive-Cote v2 on ArticularyWordRecognition: 99.33333333333333 %
# 	Hive-Cote v2 on ArticularyWordRecognition object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====
# 	Function train_model took 3.1120 seconds to execute.
# 	Function eval_model took 2.9753 seconds to execute.
# 	MultiRocket-Hydra on ArticularyWordRecognition: 99.0 %
# 	MultiRocket-Hydra on ArticularyWordRecognition object size is 0.046875 KB
# ===== AtrialFibrillation =====
# Train shape: (15, 2, 640), Test shape: (15, 2, 640)
# 	===== Rocket =====
# 	Function train_model took 0.1827 seconds to execute.
# 	Function eval_model took 0.1857 seconds to execute.
# 	Rocket on AtrialFibrillation: 6.666666666666667 %
# 	Rocket on AtrialFibrillation object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 0.3070 seconds to execute.
# 	Function eval_model took 0.3155 seconds to execute.
# 	Hydra on AtrialFibrillation: 20.0 %
# 	Hydra on AtrialFibrillation object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 9.4814 seconds to execute.
# 	Function eval_model took 6.1990 seconds to execute.
# 	Hive-Cote v2 on AtrialFibrillation: 13.333333333333334 %
# 	Hive-Cote v2 on AtrialFibrillation object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====
# 	Function train_model took 0.5633 seconds to execute.
# 	Function eval_model took 0.2779 seconds to execute.
# 	MultiRocket-Hydra on AtrialFibrillation: 6.666666666666667 %
# 	MultiRocket-Hydra on AtrialFibrillation object size is 0.046875 KB
# ===== BasicMotions =====
# Train shape: (40, 6, 100), Test shape: (40, 6, 100)
# 	===== Rocket =====
# 	Function train_model took 0.1521 seconds to execute.
# 	Function eval_model took 0.1389 seconds to execute.
# 	Rocket on BasicMotions: 100.0 %
# 	Rocket on BasicMotions object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 0.2916 seconds to execute.
# 	Function eval_model took 0.2821 seconds to execute.
# 	Hydra on BasicMotions: 100.0 %
# 	Hydra on BasicMotions object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 9.3316 seconds to execute.
# 	Function eval_model took 5.4970 seconds to execute.
# 	Hive-Cote v2 on BasicMotions: 100.0 %
# 	Hive-Cote v2 on BasicMotions object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====
# 	Function train_model took 0.3674 seconds to execute.
# 	Function eval_model took 0.3234 seconds to execute.
# 	MultiRocket-Hydra on BasicMotions: 100.0 %
# 	MultiRocket-Hydra on BasicMotions object size is 0.046875 KB
# ===== CharacterTrajectories =====
# Train shape: (1422, 3, 119), Test shape: (1436, 3, 119)
# 	===== Rocket =====
# 	Function train_model took 4.5812 seconds to execute.
# 	Function eval_model took 3.6139 seconds to execute.
# 	Rocket on CharacterTrajectories: 99.23398328690809 %
# 	Rocket on CharacterTrajectories object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 8.6369 seconds to execute.
# 	Function eval_model took 8.7616 seconds to execute.
# 	Hydra on CharacterTrajectories: 98.3983286908078 %
# 	Hydra on CharacterTrajectories object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 69.5281 seconds to execute.
# 	Function eval_model took 49.5548 seconds to execute.
# 	Hive-Cote v2 on CharacterTrajectories: 99.09470752089136 %
# 	Hive-Cote v2 on CharacterTrajectories object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====
# 	Function train_model took 10.0804 seconds to execute.
# 	Function eval_model took 5.3256 seconds to execute.
# 	MultiRocket-Hydra on CharacterTrajectories: 99.30362116991644 %
# 	MultiRocket-Hydra on CharacterTrajectories object size is 0.046875 KB
# ===== Cricket =====
# Train shape: (108, 6, 1197), Test shape: (72, 6, 1197)
# 	===== Rocket =====
# 	Function train_model took 4.3025 seconds to execute.
# 	Function eval_model took 2.9359 seconds to execute.
# 	Rocket on Cricket: 100.0 %
# 	Rocket on Cricket object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 11.7442 seconds to execute.
# 	Function eval_model took 5.1426 seconds to execute.
# 	Hydra on Cricket: 100.0 %
# 	Hydra on Cricket object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 31.3336 seconds to execute.
# 	Function eval_model took 18.3669 seconds to execute.
# 	Hive-Cote v2 on Cricket: 100.0 %
# 	Hive-Cote v2 on Cricket object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====
# 	Function train_model took 6.0482 seconds to execute.
# 	Function eval_model took 3.9506 seconds to execute.
# 	MultiRocket-Hydra on Cricket: 98.61111111111111 %
# 	MultiRocket-Hydra on Cricket object size is 0.046875 KB
# ===== DuckDuckGeese =====
# Train shape: (50, 1345, 270), Test shape: (50, 1345, 270)
# 	===== Rocket =====
# 	Function train_model took 0.8895 seconds to execute.
# 	Function eval_model took 0.7194 seconds to execute.
# 	Rocket on DuckDuckGeese: 48.0 %
# 	Rocket on DuckDuckGeese object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 0.8247 seconds to execute.
# 	Function eval_model took 0.7057 seconds to execute.
# 	Hydra on DuckDuckGeese: 70.0 %
# 	Hydra on DuckDuckGeese object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 57.0695 seconds to execute.
# 	Function eval_model took 24.3497 seconds to execute.
# 	Hive-Cote v2 on DuckDuckGeese: 30.0 %
# 	Hive-Cote v2 on DuckDuckGeese object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====
# 	Function train_model took 4.6139 seconds to execute.
# 	Function eval_model took 4.4711 seconds to execute.
# 	MultiRocket-Hydra on DuckDuckGeese: 60.0 %
# 	MultiRocket-Hydra on DuckDuckGeese object size is 0.046875 KB
# ===== Epilepsy =====
# Train shape: (137, 3, 206), Test shape: (138, 3, 206)
# 	===== Rocket =====
# 	Function train_model took 0.6400 seconds to execute.
# 	Function eval_model took 0.6065 seconds to execute.
# 	Rocket on Epilepsy: 98.55072463768117 %
# 	Rocket on Epilepsy object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 1.2190 seconds to execute.
# 	Function eval_model took 1.4077 seconds to execute.
# 	Hydra on Epilepsy: 100.0 %
# 	Hydra on Epilepsy object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 12.6819 seconds to execute.
# 	Function eval_model took 10.9235 seconds to execute.
# 	Hive-Cote v2 on Epilepsy: 100.0 %
# 	Hive-Cote v2 on Epilepsy object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====
# 	Function train_model took 1.4287 seconds to execute.
# 	Function eval_model took 1.8062 seconds to execute.
# 	MultiRocket-Hydra on Epilepsy: 100.0 %
# 	MultiRocket-Hydra on Epilepsy object size is 0.046875 KB
# ===== ERing =====
# Train shape: (30, 4, 65), Test shape: (270, 4, 65)
# 	===== Rocket =====
# 	Function train_model took 0.0830 seconds to execute.
# 	Function eval_model took 0.4605 seconds to execute.
# 	Rocket on ERing: 98.88888888888889 %
# 	Rocket on ERing object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 0.1464 seconds to execute.
# 	Function eval_model took 0.8908 seconds to execute.
# 	Hydra on ERing: 97.77777777777777 %
# 	Hydra on ERing object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 8.4735 seconds to execute.
# 	Function eval_model took 32.2207 seconds to execute.
# 	Hive-Cote v2 on ERing: 98.88888888888889 %
# 	Hive-Cote v2 on ERing object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====
# 	Function train_model took 0.3261 seconds to execute.
# 	Function eval_model took 1.7362 seconds to execute.
# 	MultiRocket-Hydra on ERing: 98.51851851851852 %
# 	MultiRocket-Hydra on ERing object size is 0.046875 KB
# ===== FingerMovements =====
# Train shape: (316, 28, 50), Test shape: (100, 28, 50)
# 	===== Rocket =====
# 	Function train_model took 0.7632 seconds to execute.
# 	Function eval_model took 0.2277 seconds to execute.
# 	Rocket on FingerMovements: 53.0 %
# 	Rocket on FingerMovements object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 2.9757 seconds to execute.
# 	Function eval_model took 0.6055 seconds to execute.
# 	Hydra on FingerMovements: 61.0 %
# 	Hydra on FingerMovements object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 19.3416 seconds to execute.
# 	Function eval_model took 5.2916 seconds to execute.
# 	Hive-Cote v2 on FingerMovements: 55.00000000000001 %
# 	Hive-Cote v2 on FingerMovements object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====
# 	Function train_model took 1.4669 seconds to execute.
# 	Function eval_model took 0.3890 seconds to execute.
# 	MultiRocket-Hydra on FingerMovements: 60.0 %
# 	MultiRocket-Hydra on FingerMovements object size is 0.046875 KB
# ===== HandMovementDirection =====
# Train shape: (160, 10, 400), Test shape: (74, 10, 400)
# 	===== Rocket =====
# 	Function train_model took 2.7342 seconds to execute.
# 	Function eval_model took 1.2936 seconds to execute.
# 	Rocket on HandMovementDirection: 51.35135135135135 %
# 	Rocket on HandMovementDirection object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 2.6730 seconds to execute.
# 	Function eval_model took 1.3690 seconds to execute.
# 	Hydra on HandMovementDirection: 29.72972972972973 %
# 	Hydra on HandMovementDirection object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 19.6939 seconds to execute.
# 	Function eval_model took 8.3088 seconds to execute.
# 	Hive-Cote v2 on HandMovementDirection: 51.35135135135135 %
# 	Hive-Cote v2 on HandMovementDirection object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====
# 	Function train_model took 3.5351 seconds to execute.
# 	Function eval_model took 1.6648 seconds to execute.
# 	MultiRocket-Hydra on HandMovementDirection: 36.486486486486484 %
# 	MultiRocket-Hydra on HandMovementDirection object size is 0.046875 KB
# ===== InsectWingbeat =====
# Train shape: (25000, 200, 20), Test shape: (25000, 200, 20)
# 	===== Rocket =====
# 	Function train_model took 3676.8611 seconds to execute.
# 	Function eval_model took 25.2795 seconds to execute.
# 	Rocket on InsectWingbeat: 38.372 %
# 	Rocket on InsectWingbeat object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 44.2798 seconds to execute.
# 	Function eval_model took 23.4023 seconds to execute.
# 	Hydra on InsectWingbeat: 66.756 %
# 	Hydra on InsectWingbeat object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 75313.3952 seconds to execute.
# 	Function eval_model took 2258.9075 seconds to execute.
# 	Hive-Cote v2 on InsectWingbeat: 58.187999999999995 %
# 	Hive-Cote v2 on InsectWingbeat object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====

# %%
UEA_MTSC30 = [
    # 'EthanolConcentration',
#               'FaceDetection',
#               'Handwriting',
#               'Heartbeat',
#               'JapaneseVowels',
#               'PEMS-SF',
#               'SelfRegulationSCP1',
#               'SelfRegulationSCP2',
#               'SpokenArabicDigits',
#               'UWaveGestureLibrary',
#               'ArticularyWordRecognition',
#               'AtrialFibrillation',
#               'BasicMotions',
#               'CharacterTrajectories',
#               'Cricket',
#               'DuckDuckGeese',
#               'Epilepsy',
#               'ERing',
#               'FingerMovements',
#               'HandMovementDirection',
              'InsectWingbeat',
              'Libras',
              'LSST',
              'MotorImagery',
              'NATOPS',
              'PenDigits',
              'PhonemeSpectra',
              'RacketSports',
              'StandWalkJump',
              'EigenWorms',]

models = {
    # 'DTW': DTWClassifier(n_jobs=8),  # result will be same regardless of random_state
    'Rocket': RocketClassifier(random_state=SEED, n_jobs=8),
    'Hydra': HydraClassifier(random_state=SEED, n_jobs=8),
    'Hive-Cote v2': HIVECOTEV2(time_limit_in_minutes=0.2, random_state=SEED, n_jobs=8),
    'MultiRocket-Hydra': MultiRocketHydraClassifier(random_state=SEED, n_jobs=8),
}
for dname in UEA_MTSC30:
    print(f"===== {dname} =====")
    X_train, y_train = load_classification(dname, split="train", extract_path=data_dir, load_equal_length=True)
    X_test, y_test = load_classification(dname, split="test", extract_path=data_dir, load_equal_length=True)
    print(f"Train shape: {X_train.shape}, Test shape: {X_test.shape}")
    
    for model in models:
        print(f"\t===== {model} =====")
        # paddding to make the length >= 9
        if X_train.shape[2] < 10 and model == 'MultiRocket-Hydra':
            X_train = np.pad(X_train, ((0, 0), (0, 0), (0, 10 - X_train.shape[2])), 'edge')
            X_test = np.pad(X_test, ((0, 0), (0, 0), (0, 10 - X_test.shape[2])), 'edge')
            print(f"\tPadded Train shape: {X_train.shape}, Padded Test shape: {X_test.shape}")
        
        random.seed(SEED)
        np.random.seed(SEED)
        models[model] = train_model(models[model], X_train, y_train)
        accuracy = eval_model(models[model], X_test, y_test)
        print(f"\t{model} on {dname}: {accuracy * 100} %")
        print(f"\t{model} on {dname} object size is {sys.getsizeof(models[model])/1024} KB")
        models[model].reset(keep=None)
        gc.collect()
# Out:
# ===== InsectWingbeat =====
# Train shape: (25000, 200, 20), Test shape: (25000, 200, 20)
# 	===== Rocket =====
# 	Function train_model took 3844.5500 seconds to execute.
# 	Function eval_model took 25.5611 seconds to execute.
# 	Rocket on InsectWingbeat: 38.372 %
# 	Rocket on InsectWingbeat object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 44.2460 seconds to execute.
# 	Function eval_model took 31.3472 seconds to execute.
# 	Hydra on InsectWingbeat: 66.756 %
# 	Hydra on InsectWingbeat object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 74870.6334 seconds to execute.
# 	Function eval_model took 2198.0961 seconds to execute.
# 	Hive-Cote v2 on InsectWingbeat: 58.187999999999995 %
# 	Hive-Cote v2 on InsectWingbeat object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====
# 	Function train_model took 3761.1494 seconds to execute.
# 	Function eval_model took 119.6503 seconds to execute.
# 	MultiRocket-Hydra on InsectWingbeat: 65.744 %
# 	MultiRocket-Hydra on InsectWingbeat object size is 0.046875 KB
# ===== Libras =====
# Train shape: (180, 2, 45), Test shape: (180, 2, 45)
# 	===== Rocket =====
# 	Function train_model took 0.3036 seconds to execute.
# 	Function eval_model took 0.1854 seconds to execute.
# 	Rocket on Libras: 90.0 %
# 	Rocket on Libras object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 0.5634 seconds to execute.
# 	Function eval_model took 0.5020 seconds to execute.
# 	Hydra on Libras: 93.33333333333333 %
# 	Hydra on Libras object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 11.9105 seconds to execute.
# 	Function eval_model took 8.5699 seconds to execute.
# 	Hive-Cote v2 on Libras: 91.66666666666666 %
# 	Hive-Cote v2 on Libras object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====
# 	Function train_model took 0.8264 seconds to execute.
# 	Function eval_model took 0.6061 seconds to execute.
# 	MultiRocket-Hydra on Libras: 93.33333333333333 %
# 	MultiRocket-Hydra on Libras object size is 0.046875 KB
# ===== LSST =====
# Train shape: (2459, 6, 36), Test shape: (2466, 6, 36)
# 	===== Rocket =====
# 	Function train_model took 7.4100 seconds to execute.
# 	Function eval_model took 3.0106 seconds to execute.
# 	Rocket on LSST: 64.0308191403082 %
# 	Rocket on LSST object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 13.6784 seconds to execute.
# 	Function eval_model took 11.0088 seconds to execute.
# 	Hydra on LSST: 60.98945660989457 %
# 	Hydra on LSST object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 185.7048 seconds to execute.
# 	Function eval_model took 78.0089 seconds to execute.
# 	Hive-Cote v2 on LSST: 65.81508515815085 %
# 	Hive-Cote v2 on LSST object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====
# 	Function train_model took 20.1035 seconds to execute.
# 	Function eval_model took 13.8463 seconds to execute.
# 	MultiRocket-Hydra on LSST: 62.165450121654494 %
# 	MultiRocket-Hydra on LSST object size is 0.046875 KB
# ===== MotorImagery =====
# Train shape: (278, 64, 3000), Test shape: (100, 64, 3000)
# 	===== Rocket =====
# 	Function train_model took 39.8176 seconds to execute.
# 	Function eval_model took 14.4539 seconds to execute.
# 	Rocket on MotorImagery: 50.0 %
# 	Rocket on MotorImagery object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 33.6568 seconds to execute.
# 	Function eval_model took 18.3146 seconds to execute.
# 	Hydra on MotorImagery: 50.0 %
# 	Hydra on MotorImagery object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 710.5094 seconds to execute.
# 	Function eval_model took 257.2872 seconds to execute.
# 	Hive-Cote v2 on MotorImagery: 54.0 %
# 	Hive-Cote v2 on MotorImagery object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====
# 	Function train_model took 49.5262 seconds to execute.
# 	Function eval_model took 17.3951 seconds to execute.
# 	MultiRocket-Hydra on MotorImagery: 50.0 %
# 	MultiRocket-Hydra on MotorImagery object size is 0.046875 KB
# ===== NATOPS =====
# Train shape: (180, 24, 51), Test shape: (180, 24, 51)
# 	===== Rocket =====
# 	Function train_model took 0.4743 seconds to execute.
# 	Function eval_model took 0.4202 seconds to execute.
# 	Rocket on NATOPS: 89.44444444444444 %
# 	Rocket on NATOPS object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 0.6690 seconds to execute.
# 	Function eval_model took 0.6240 seconds to execute.
# 	Hydra on NATOPS: 88.88888888888889 %
# 	Hydra on NATOPS object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 12.9473 seconds to execute.
# 	Function eval_model took 8.9121 seconds to execute.
# 	Hive-Cote v2 on NATOPS: 90.0 %
# 	Hive-Cote v2 on NATOPS object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====
# 	Function train_model took 0.9632 seconds to execute.
# 	Function eval_model took 0.9583 seconds to execute.
# 	MultiRocket-Hydra on NATOPS: 90.55555555555556 %
# 	MultiRocket-Hydra on NATOPS object size is 0.046875 KB
# ===== PenDigits =====
# Train shape: (7494, 2, 8), Test shape: (3498, 2, 8)
# 	===== Rocket =====
# 	Function train_model took 97.0670 seconds to execute.
# 	Function eval_model took 1.0839 seconds to execute.
# 	Rocket on PenDigits: 98.22755860491709 %
# 	Rocket on PenDigits object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 2.8254 seconds to execute.
# 	Function eval_model took 0.3577 seconds to execute.
# 	Hydra on PenDigits: 96.22641509433963 %
# 	Hydra on PenDigits object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 1978.5095 seconds to execute.
# 	Function eval_model took 104.3077 seconds to execute.
# 	Hive-Cote v2 on PenDigits: 97.85591766723843 %
# 	Hive-Cote v2 on PenDigits object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====
# 	Padded Train shape: (7494, 2, 10), Padded Test shape: (3498, 2, 10)
# 	Function train_model took 119.6643 seconds to execute.
# 	Function eval_model took 2.8226 seconds to execute.
# 	MultiRocket-Hydra on PenDigits: 97.284162378502 %
# 	MultiRocket-Hydra on PenDigits object size is 0.046875 KB
# ===== PhonemeSpectra =====
# Train shape: (3315, 11, 217), Test shape: (3353, 11, 217)
# 	===== Rocket =====
# 	Function train_model took 42.0639 seconds to execute.
# 	Function eval_model took 31.7502 seconds to execute.
# 	Rocket on PhonemeSpectra: 27.497763197136894 %
# 	Rocket on PhonemeSpectra object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 44.5312 seconds to execute.
# 	Function eval_model took 36.2477 seconds to execute.
# 	Hydra on PhonemeSpectra: 33.01521025946913 %
# 	Hydra on PhonemeSpectra object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 864.6358 seconds to execute.
# 	Function eval_model took 709.1562 seconds to execute.
# 	Hive-Cote v2 on PhonemeSpectra: 29.91351028929317 %
# 	Hive-Cote v2 on PhonemeSpectra object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====
# 	Function train_model took 58.9154 seconds to execute.
# 	Function eval_model took 46.9349 seconds to execute.
# 	MultiRocket-Hydra on PhonemeSpectra: 33.64151506113927 %
# 	MultiRocket-Hydra on PhonemeSpectra object size is 0.046875 KB
# ===== RacketSports =====
# Train shape: (151, 6, 30), Test shape: (152, 6, 30)
# 	===== Rocket =====
# 	Function train_model took 0.2049 seconds to execute.
# 	Function eval_model took 0.1749 seconds to execute.
# 	Rocket on RacketSports: 90.78947368421053 %
# 	Rocket on RacketSports object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 0.2868 seconds to execute.
# 	Function eval_model took 0.2597 seconds to execute.
# 	Hydra on RacketSports: 88.1578947368421 %
# 	Hydra on RacketSports object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 12.1051 seconds to execute.
# 	Function eval_model took 8.3912 seconds to execute.
# 	Hive-Cote v2 on RacketSports: 90.78947368421053 %
# 	Hive-Cote v2 on RacketSports object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====
# 	Function train_model took 0.4584 seconds to execute.
# 	Function eval_model took 0.3521 seconds to execute.
# 	MultiRocket-Hydra on RacketSports: 90.13157894736842 %
# 	MultiRocket-Hydra on RacketSports object size is 0.046875 KB
# ===== StandWalkJump =====
# Train shape: (12, 4, 2500), Test shape: (15, 4, 2500)
# 	===== Rocket =====
# 	Function train_model took 0.8718 seconds to execute.
# 	Function eval_model took 0.9676 seconds to execute.
# 	Rocket on StandWalkJump: 46.666666666666664 %
# 	Rocket on StandWalkJump object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 1.2684 seconds to execute.
# 	Function eval_model took 1.5421 seconds to execute.
# 	Hydra on StandWalkJump: 40.0 %
# 	Hydra on StandWalkJump object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 12.4363 seconds to execute.
# 	Function eval_model took 11.4773 seconds to execute.
# 	Hive-Cote v2 on StandWalkJump: 40.0 %
# 	Hive-Cote v2 on StandWalkJump object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====
# 	Function train_model took 2.4157 seconds to execute.
# 	Function eval_model took 1.7050 seconds to execute.
# 	MultiRocket-Hydra on StandWalkJump: 40.0 %
# 	MultiRocket-Hydra on StandWalkJump object size is 0.046875 KB
# ===== EigenWorms =====
# Train shape: (128, 6, 17984), Test shape: (131, 6, 17984)
# 	===== Rocket =====
# 	Function train_model took 79.6938 seconds to execute.
# 	Function eval_model took 82.5888 seconds to execute.
# 	Rocket on EigenWorms: 89.31297709923665 %
# 	Rocket on EigenWorms object size is 0.046875 KB
# 	===== Hydra =====
# 	Function train_model took 104.9231 seconds to execute.
# 	Function eval_model took 106.8421 seconds to execute.
# 	Hydra on EigenWorms: 96.18320610687023 %
# 	Hydra on EigenWorms object size is 0.046875 KB
# 	===== Hive-Cote v2 =====
# 	Function train_model took 2406.2466 seconds to execute.
# 	Function eval_model took 1804.8196 seconds to execute.
# 	Hive-Cote v2 on EigenWorms: 92.36641221374046 %
# 	Hive-Cote v2 on EigenWorms object size is 0.046875 KB
# 	===== MultiRocket-Hydra =====
# 	Function train_model took 163.6697 seconds to execute.
# 	Function eval_model took 144.8867 seconds to execute.
# 	MultiRocket-Hydra on EigenWorms: 96.18320610687023 %
# 	MultiRocket-Hydra on EigenWorms object size is 0.046875 KB
